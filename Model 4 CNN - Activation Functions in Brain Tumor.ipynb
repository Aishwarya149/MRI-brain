# %% [markdown]
# **Taking the best layers 3, kernel size, optimizer RMSprop and find the best activation function**

# %%
import imageio as Brain_tumorIGo
from matplotlib import pyplot as Brain_tumorOTp
import numpy as Brain_tumorPyn
import warnings as Brain_tumorWrn
Brain_tumorWrn.filterwarnings("ignore")

# %%
Route_of_Image='/content/drive/MyDrive/Sep-Dec 2024 Batch/Vanitha (Sep-Dec 2024)/Minimised CNN for Multi-Class Brain Tumor Detection in MRI Scans/Code/MRI DATA/'

# %%
Brain_Tumor_Fi_1='training'
Brain_Tumor_Fi_2='validation'
Brain_Tumor_Fi_se=2
Brain_Tumor_Fi_size=(244,244)
Brain_Tumor_Fi_div=0.2

from tensorflow.keras.utils import image_dataset_from_directory as Brain_tumorASD

# Define the image size to match the model's input shape
Brain_Tumor_Fi_size = (224, 224)

Brain_tumor_TT = Brain_tumorASD(
    Route_of_Image,
    validation_split=Brain_Tumor_Fi_div,
    subset=Brain_Tumor_Fi_1,
    seed=Brain_Tumor_Fi_se,
    image_size=Brain_Tumor_Fi_size,
    batch_size=100
)
Brain_tumor_VV = Brain_tumorASD(
    Route_of_Image,
    validation_split=Brain_Tumor_Fi_div,
    subset=Brain_Tumor_Fi_2,
    seed=Brain_Tumor_Fi_se,
    image_size=Brain_Tumor_Fi_size,
    batch_size=100
)
# Out:
# Found 1311 files belonging to 4 classes.
# Using 1049 files for training.
# Found 1311 files belonging to 4 classes.
# Using 262 files for validation.

# %%
Brain_tumor_SS = (224, 224, 3)
Brain_tumor_S = 'softmax'
Brain_tumor_LL = 'SparseCategoricalCrossentropy'

Brain_tumor_KR = (4, 4)
from tensorflow.keras.optimizers import RMSprop as Brain_tumor_OO
Brain_tumor_OOV = Brain_tumor_OO(learning_rate=0.0001)

from tensorflow.keras.models import Sequential as Brain_tumorASD1
from tensorflow.keras.layers import Conv2D as Brain_tumorASD2
from tensorflow.keras.layers import MaxPooling2D as Brain_tumorASD3
from tensorflow.keras.layers import Dense as Brain_tumorASD4
from tensorflow.keras.layers import Flatten as Brain_tumorASD5
from tensorflow.keras.layers import BatchNormalization as Brain_tumorASD6

# %% [markdown]
# ## **Model 4 - Activation Functions**

# %% [markdown]
# ### Sigmoid Activation

# %%
Brain_tumor_AA = 'sigmoid'
melanoma_FPq = Brain_tumorASD1([
    Brain_tumorASD2(32, kernel_size=Brain_tumor_KR, activation=Brain_tumor_AA, padding='same', input_shape=Brain_tumor_SS),
    Brain_tumorASD3(pool_size=(4,4)),

    Brain_tumorASD2(64, kernel_size=Brain_tumor_KR, activation=Brain_tumor_AA),
    Brain_tumorASD3(pool_size=(4,4)),
    Brain_tumorASD5(),

    Brain_tumorASD4(64, activation=Brain_tumor_AA),

    Brain_tumorASD4(4, activation='softmax')
    ])
melanoma_FPq.compile(optimizer= Brain_tumor_OOV, loss= Brain_tumor_LL, metrics=['accuracy'])
Brain_tumor_Hs =melanoma_FPq.fit(Brain_tumor_TT, validation_data= Brain_tumor_VV, epochs=10, batch_size=1000)
# Out:
# Epoch 1/10
# 11/11 [==============================] - 212s 11s/step - loss: 1.4863 - accuracy: 0.2545 - val_loss: 1.4178 - val_accuracy: 0.1870
# Epoch 2/10
# 11/11 [==============================] - 69s 6s/step - loss: 1.3942 - accuracy: 0.2755 - val_loss: 1.3654 - val_accuracy: 0.3473
# Epoch 3/10
# 11/11 [==============================] - 69s 6s/step - loss: 1.3677 - accuracy: 0.3051 - val_loss: 1.3821 - val_accuracy: 0.3473
# Epoch 4/10
# 11/11 [==============================] - 71s 6s/step - loss: 1.3796 - accuracy: 0.2765 - val_loss: 1.3290 - val_accuracy: 0.4351
# Epoch 5/10
# 11/11 [==============================] - 67s 6s/step - loss: 1.3547 - accuracy: 0.3079 - val_loss: 1.5685 - val_accuracy: 0.1832
# Epoch 6/10
# 11/11 [==============================] - 66s 6s/step - loss: 1.3600 - accuracy: 0.3213 - val_loss: 1.3062 - val_accuracy: 0.3473
# Epoch 7/10
# 11/11 [==============================] - 65s 6s/step - loss: 1.3194 - accuracy: 0.3422 - val_loss: 1.2611 - val_accuracy: 0.5382
# Epoch 8/10
# 11/11 [==============================] - 72s 6s/step - loss: 1.3093 - accuracy: 0.3813 - val_loss: 1.2382 - val_accuracy: 0.5649
# Epoch 9/10
# 11/11 [==============================] - 65s 5s/step - loss: 1.3028 - accuracy: 0.3737 - val_loss: 1.2492 - val_accuracy: 0.4580
# Epoch 10/10
# 11/11 [==============================] - 64s 6s/step - loss: 1.2743 - accuracy: 0.3918 - val_loss: 1.2178 - val_accuracy: 0.4809

# %%
melanoma_FPq.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      1568
#
#  max_pooling2d (MaxPooling2  (None, 56, 56, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 53, 53, 64)        32832
#
#  max_pooling2d_1 (MaxPoolin  (None, 13, 13, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 10816)             0
#
#  dense (Dense)               (None, 64)                692288
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 726948 (2.77 MB)
# Trainable params: 726948 (2.77 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Tanh Activation

# %%
Brain_tumor_OOV = Brain_tumor_OO(learning_rate=0.0001)
Brain_tumor_AA = 'tanh'
melanoma_FPq = Brain_tumorASD1([
    Brain_tumorASD2(32, kernel_size=Brain_tumor_KR, activation=Brain_tumor_AA, padding='same', input_shape=Brain_tumor_SS),
    Brain_tumorASD3(pool_size=(4,4)),

    Brain_tumorASD2(64, kernel_size=Brain_tumor_KR, activation=Brain_tumor_AA),
    Brain_tumorASD3(pool_size=(4,4)),
    Brain_tumorASD5(),

    Brain_tumorASD4(64, activation=Brain_tumor_AA),

    Brain_tumorASD4(4, activation='softmax')
    ])
melanoma_FPq.compile(optimizer= Brain_tumor_OOV, loss= Brain_tumor_LL, metrics=['accuracy'])
Brain_tumor_Hs =melanoma_FPq.fit(Brain_tumor_TT, validation_data= Brain_tumor_VV, epochs=10, batch_size=1000)
# Out:
# Epoch 1/10
# 11/11 [==============================] - 66s 6s/step - loss: 1.6775 - accuracy: 0.4233 - val_loss: 1.0409 - val_accuracy: 0.5153
# Epoch 2/10
# 11/11 [==============================] - 64s 5s/step - loss: 0.9566 - accuracy: 0.6092 - val_loss: 0.8153 - val_accuracy: 0.6145
# Epoch 3/10
# 11/11 [==============================] - 62s 5s/step - loss: 0.7128 - accuracy: 0.7226 - val_loss: 0.6875 - val_accuracy: 0.7137
# Epoch 4/10
# 11/11 [==============================] - 62s 5s/step - loss: 0.6497 - accuracy: 0.7464 - val_loss: 0.5586 - val_accuracy: 0.7863
# Epoch 5/10
# 11/11 [==============================] - 70s 6s/step - loss: 0.4862 - accuracy: 0.8198 - val_loss: 0.5175 - val_accuracy: 0.8092
# Epoch 6/10
# 11/11 [==============================] - 63s 5s/step - loss: 0.4211 - accuracy: 0.8465 - val_loss: 0.5460 - val_accuracy: 0.7901
# Epoch 7/10
# 11/11 [==============================] - 62s 5s/step - loss: 0.3863 - accuracy: 0.8589 - val_loss: 0.4336 - val_accuracy: 0.8168
# Epoch 8/10
# 11/11 [==============================] - 62s 5s/step - loss: 0.3271 - accuracy: 0.8856 - val_loss: 0.4272 - val_accuracy: 0.8321
# Epoch 9/10
# 11/11 [==============================] - 62s 5s/step - loss: 0.2743 - accuracy: 0.9266 - val_loss: 0.3785 - val_accuracy: 0.8702
# Epoch 10/10
# 11/11 [==============================] - 63s 5s/step - loss: 0.2606 - accuracy: 0.9237 - val_loss: 0.3546 - val_accuracy: 0.8702

# %%
melanoma_FPq.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 224, 224, 32)      1568
#
#  max_pooling2d_4 (MaxPoolin  (None, 56, 56, 32)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 53, 53, 64)        32832
#
#  max_pooling2d_5 (MaxPoolin  (None, 13, 13, 64)        0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 10816)             0
#
#  dense_4 (Dense)             (None, 64)                692288
#
#  dense_5 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 726948 (2.77 MB)
# Trainable params: 726948 (2.77 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Relu Activation

# %%
Brain_tumor_OOV = Brain_tumor_OO(learning_rate=0.0001)
Brain_tumor_AA = 'relu'
melanoma_FPq = Brain_tumorASD1([
    Brain_tumorASD2(32, kernel_size=Brain_tumor_KR, activation=Brain_tumor_AA, padding='same', input_shape=Brain_tumor_SS),
    Brain_tumorASD3(pool_size=(4,4)),

    Brain_tumorASD2(64, kernel_size=Brain_tumor_KR, activation=Brain_tumor_AA),
    Brain_tumorASD3(pool_size=(4,4)),
    Brain_tumorASD5(),

    Brain_tumorASD4(64, activation=Brain_tumor_AA),

    Brain_tumorASD4(4, activation='softmax')
    ])
melanoma_FPq.compile(optimizer= Brain_tumor_OOV, loss= Brain_tumor_LL, metrics=['accuracy'])
Brain_tumor_Hs =melanoma_FPq.fit(Brain_tumor_TT, validation_data= Brain_tumor_VV, epochs=10, batch_size=1000)
# Out:
# Epoch 1/10
# 11/11 [==============================] - 64s 5s/step - loss: 27.1905 - accuracy: 0.3241 - val_loss: 8.5993 - val_accuracy: 0.2557
# Epoch 2/10
# 11/11 [==============================] - 61s 5s/step - loss: 5.4684 - accuracy: 0.4423 - val_loss: 2.2505 - val_accuracy: 0.5382
# Epoch 3/10
# 11/11 [==============================] - 71s 6s/step - loss: 3.1454 - accuracy: 0.5091 - val_loss: 5.3423 - val_accuracy: 0.3740
# Epoch 4/10
# 11/11 [==============================] - 62s 5s/step - loss: 2.1608 - accuracy: 0.6015 - val_loss: 1.8082 - val_accuracy: 0.5954
# Epoch 5/10
# 11/11 [==============================] - 60s 5s/step - loss: 2.6496 - accuracy: 0.5567 - val_loss: 1.5351 - val_accuracy: 0.6718
# Epoch 6/10
# 11/11 [==============================] - 60s 5s/step - loss: 1.2627 - accuracy: 0.6787 - val_loss: 2.1634 - val_accuracy: 0.6679
# Epoch 7/10
# 11/11 [==============================] - 61s 5s/step - loss: 2.0038 - accuracy: 0.6130 - val_loss: 1.2832 - val_accuracy: 0.6336
# Epoch 8/10
# 11/11 [==============================] - 61s 5s/step - loss: 0.8420 - accuracy: 0.7245 - val_loss: 2.8699 - val_accuracy: 0.4160
# Epoch 9/10
# 11/11 [==============================] - 60s 5s/step - loss: 1.2440 - accuracy: 0.6826 - val_loss: 4.8594 - val_accuracy: 0.4847
# Epoch 10/10
# 11/11 [==============================] - 60s 5s/step - loss: 0.8929 - accuracy: 0.7588 - val_loss: 0.9374 - val_accuracy: 0.7557

# %%
melanoma_FPq.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 224, 224, 32)      1568
#
#  max_pooling2d_6 (MaxPoolin  (None, 56, 56, 32)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 53, 53, 64)        32832
#
#  max_pooling2d_7 (MaxPoolin  (None, 13, 13, 64)        0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 10816)             0
#
#  dense_6 (Dense)             (None, 64)                692288
#
#  dense_7 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 726948 (2.77 MB)
# Trainable params: 726948 (2.77 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Tanh Activation is best.
