# %% [markdown]
# **Taking the best layers 3, kernel size 4 and find the best optimizer**

# %%
import imageio as Brain_tumorIGo
from matplotlib import pyplot as Brain_tumorOTp
import numpy as Brain_tumorPyn
import warnings as Brain_tumorWrn
Brain_tumorWrn.filterwarnings("ignore")

# %%
Route_of_Image='/MRI DATA/'

# %%
Brain_Tumor_Fi_1='training'
Brain_Tumor_Fi_2='validation'
Brain_Tumor_Fi_se=2
Brain_Tumor_Fi_size=(244,244)
Brain_Tumor_Fi_div=0.2

from tensorflow.keras.utils import image_dataset_from_directory as Brain_tumorASD

# Define the image size to match the model's input shape
Brain_Tumor_Fi_size = (224, 224)

Brain_tumor_TT = Brain_tumorASD(
    Route_of_Image,
    validation_split=Brain_Tumor_Fi_div,
    subset=Brain_Tumor_Fi_1,
    seed=Brain_Tumor_Fi_se,
    image_size=Brain_Tumor_Fi_size,
    batch_size=100
)
Brain_tumor_VV = Brain_tumorASD(
    Route_of_Image,
    validation_split=Brain_Tumor_Fi_div,
    subset=Brain_Tumor_Fi_2,
    seed=Brain_Tumor_Fi_se,
    image_size=Brain_Tumor_Fi_size,
    batch_size=100
)
# Out:
# Found 1311 files belonging to 4 classes.
# Using 1049 files for training.
# Found 1311 files belonging to 4 classes.
# Using 262 files for validation.

# %%
Brain_tumor_AA = 'tanh'
Brain_tumor_SS = (224, 224, 3)
Brain_tumor_S = 'softmax'
Brain_tumor_LL = 'SparseCategoricalCrossentropy'

#from keras.optimizers import Adam as Brain_tumor_OO
#Brain_tumor_OOV = Brain_tumor_OO(learning_rate=0.0001)
from tensorflow.keras.models import Sequential as Brain_tumorASD1
from tensorflow.keras.layers import Conv2D as Brain_tumorASD2
from tensorflow.keras.layers import MaxPooling2D as Brain_tumorASD3
from tensorflow.keras.layers import Dense as Brain_tumorASD4
from tensorflow.keras.layers import Flatten as Brain_tumorASD5
from tensorflow.keras.layers import BatchNormalization as Brain_tumorASD6

# %% [markdown]
# ## **Model 3 - Optimizers**

# %% [markdown]
# ### Adagrad Optimizer

# %%
from keras.optimizers import Adagrad as Brain_tumor_OO
Brain_tumor_OOV = Brain_tumor_OO(learning_rate=0.0001)
Brain_tumor_KR = (4, 4)
melanoma_FPq = Brain_tumorASD1([
    Brain_tumorASD2(32, kernel_size=Brain_tumor_KR, activation=Brain_tumor_AA, padding='same', input_shape=Brain_tumor_SS),
    Brain_tumorASD3(pool_size=(4,4)),

    Brain_tumorASD2(64, kernel_size=Brain_tumor_KR, activation=Brain_tumor_AA),
    Brain_tumorASD3(pool_size=(4,4)),
    Brain_tumorASD5(),

    Brain_tumorASD4(64, activation=Brain_tumor_AA),

    Brain_tumorASD4(4, activation='softmax')
    ])
melanoma_FPq.compile(optimizer= Brain_tumor_OOV, loss= Brain_tumor_LL, metrics=['accuracy'])
Brain_tumor_Hs =melanoma_FPq.fit(Brain_tumor_TT, validation_data= Brain_tumor_VV, epochs=10, batch_size=1000)
# Out:
# Epoch 1/10
# 11/11 [==============================] - 69s 6s/step - loss: 1.4634 - accuracy: 0.2574 - val_loss: 1.3712 - val_accuracy: 0.2939
# Epoch 2/10
# 11/11 [==============================] - 67s 6s/step - loss: 1.3527 - accuracy: 0.2946 - val_loss: 1.3254 - val_accuracy: 0.3435
# Epoch 3/10
# 11/11 [==============================] - 66s 6s/step - loss: 1.3054 - accuracy: 0.3441 - val_loss: 1.2807 - val_accuracy: 0.3626
# Epoch 4/10
# 11/11 [==============================] - 66s 6s/step - loss: 1.2677 - accuracy: 0.3775 - val_loss: 1.2420 - val_accuracy: 0.4389
# Epoch 5/10
# 11/11 [==============================] - 66s 6s/step - loss: 1.2345 - accuracy: 0.4414 - val_loss: 1.2265 - val_accuracy: 0.4427
# Epoch 6/10
# 11/11 [==============================] - 68s 6s/step - loss: 1.2054 - accuracy: 0.4862 - val_loss: 1.1954 - val_accuracy: 0.5000
# Epoch 7/10
# 11/11 [==============================] - 65s 6s/step - loss: 1.1781 - accuracy: 0.5157 - val_loss: 1.1582 - val_accuracy: 0.5420
# Epoch 8/10
# 11/11 [==============================] - 73s 6s/step - loss: 1.1557 - accuracy: 0.5462 - val_loss: 1.1403 - val_accuracy: 0.5496
# Epoch 9/10
# 11/11 [==============================] - 69s 6s/step - loss: 1.1332 - accuracy: 0.5682 - val_loss: 1.1204 - val_accuracy: 0.5611
# Epoch 10/10
# 11/11 [==============================] - 65s 6s/step - loss: 1.1133 - accuracy: 0.5939 - val_loss: 1.1052 - val_accuracy: 0.5649

# %%
melanoma_FPq.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      1568
#
#  max_pooling2d (MaxPooling2  (None, 56, 56, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 53, 53, 64)        32832
#
#  max_pooling2d_1 (MaxPoolin  (None, 13, 13, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 10816)             0
#
#  dense (Dense)               (None, 64)                692288
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 726948 (2.77 MB)
# Trainable params: 726948 (2.77 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### RMSprop Optimizer

# %%
from tensorflow.keras.optimizers import RMSprop as Brain_tumor_OO

Brain_tumor_OOV = Brain_tumor_OO(learning_rate=0.0001)
Brain_tumor_KR = (4, 4)
melanoma_FPq = Brain_tumorASD1([
    Brain_tumorASD2(32, kernel_size=Brain_tumor_KR, activation=Brain_tumor_AA, padding='same', input_shape=Brain_tumor_SS),
    Brain_tumorASD3(pool_size=(4,4)),

    Brain_tumorASD2(64, kernel_size=Brain_tumor_KR, activation=Brain_tumor_AA),
    Brain_tumorASD3(pool_size=(4,4)),
    Brain_tumorASD5(),

    Brain_tumorASD4(64, activation=Brain_tumor_AA),

    Brain_tumorASD4(4, activation='softmax')
    ])
melanoma_FPq.compile(optimizer= Brain_tumor_OOV, loss= Brain_tumor_LL, metrics=['accuracy'])
Brain_tumor_Hs =melanoma_FPq.fit(Brain_tumor_TT, validation_data= Brain_tumor_VV, epochs=10, batch_size=1000)
# Out:
# Epoch 1/10
# 11/11 [==============================] - 67s 6s/step - loss: 1.6908 - accuracy: 0.3966 - val_loss: 1.0484 - val_accuracy: 0.5573
# Epoch 2/10
# 11/11 [==============================] - 65s 6s/step - loss: 0.9378 - accuracy: 0.6206 - val_loss: 0.8738 - val_accuracy: 0.6183
# Epoch 3/10
# 11/11 [==============================] - 65s 6s/step - loss: 0.7191 - accuracy: 0.7150 - val_loss: 0.6513 - val_accuracy: 0.7252
# Epoch 4/10
# 11/11 [==============================] - 70s 6s/step - loss: 0.6134 - accuracy: 0.7598 - val_loss: 0.5431 - val_accuracy: 0.7977
# Epoch 5/10
# 11/11 [==============================] - 64s 6s/step - loss: 0.4986 - accuracy: 0.8189 - val_loss: 0.5529 - val_accuracy: 0.7901
# Epoch 6/10
# 11/11 [==============================] - 77s 6s/step - loss: 0.4127 - accuracy: 0.8561 - val_loss: 0.4584 - val_accuracy: 0.8244
# Epoch 7/10
# 11/11 [==============================] - 64s 5s/step - loss: 0.4028 - accuracy: 0.8465 - val_loss: 0.4202 - val_accuracy: 0.8359
# Epoch 8/10
# 11/11 [==============================] - 64s 6s/step - loss: 0.3271 - accuracy: 0.8808 - val_loss: 0.3905 - val_accuracy: 0.8626
# Epoch 9/10
# 11/11 [==============================] - 69s 6s/step - loss: 0.2823 - accuracy: 0.9113 - val_loss: 0.4442 - val_accuracy: 0.8168
# Epoch 10/10
# 11/11 [==============================] - 65s 6s/step - loss: 0.2586 - accuracy: 0.9180 - val_loss: 0.4362 - val_accuracy: 0.8130

# %%
melanoma_FPq.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 224, 224, 32)      1568
#
#  max_pooling2d_2 (MaxPoolin  (None, 56, 56, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 53, 53, 64)        32832
#
#  max_pooling2d_3 (MaxPoolin  (None, 13, 13, 64)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 10816)             0
#
#  dense_2 (Dense)             (None, 64)                692288
#
#  dense_3 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 726948 (2.77 MB)
# Trainable params: 726948 (2.77 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### SGD Optimizer

# %%
from tensorflow.keras.optimizers import SGD as Brain_tumor_OO
Brain_tumor_OOV = Brain_tumor_OO(learning_rate=0.0001)
Brain_tumor_KR = (4, 4)
melanoma_FPq = Brain_tumorASD1([
    Brain_tumorASD2(32, kernel_size=Brain_tumor_KR, activation=Brain_tumor_AA, padding='same', input_shape=Brain_tumor_SS),
    Brain_tumorASD3(pool_size=(4,4)),

    Brain_tumorASD2(64, kernel_size=Brain_tumor_KR, activation=Brain_tumor_AA),
    Brain_tumorASD3(pool_size=(4,4)),
    Brain_tumorASD5(),

    Brain_tumorASD4(64, activation=Brain_tumor_AA),

    Brain_tumorASD4(4, activation='softmax')
    ])
melanoma_FPq.compile(optimizer= Brain_tumor_OOV, loss= Brain_tumor_LL, metrics=['accuracy'])
Brain_tumor_Hs =melanoma_FPq.fit(Brain_tumor_TT, validation_data= Brain_tumor_VV, epochs=10, batch_size=1000)
# Out:
# Epoch 1/10
# 11/11 [==============================] - 73s 6s/step - loss: 1.4544 - accuracy: 0.3251 - val_loss: 1.3883 - val_accuracy: 0.3397
# Epoch 2/10
# 11/11 [==============================] - 78s 6s/step - loss: 1.3828 - accuracy: 0.3251 - val_loss: 1.3504 - val_accuracy: 0.3397
# Epoch 3/10
# 11/11 [==============================] - 87s 7s/step - loss: 1.3528 - accuracy: 0.3317 - val_loss: 1.3261 - val_accuracy: 0.3626
# Epoch 4/10
# 11/11 [==============================] - 75s 6s/step - loss: 1.3343 - accuracy: 0.3508 - val_loss: 1.3077 - val_accuracy: 0.3969
# Epoch 5/10
# 11/11 [==============================] - 71s 6s/step - loss: 1.3202 - accuracy: 0.3746 - val_loss: 1.2961 - val_accuracy: 0.4084
# Epoch 6/10
# 11/11 [==============================] - 67s 6s/step - loss: 1.3080 - accuracy: 0.3861 - val_loss: 1.2823 - val_accuracy: 0.4275
# Epoch 7/10
# 11/11 [==============================] - 65s 6s/step - loss: 1.2970 - accuracy: 0.4099 - val_loss: 1.2717 - val_accuracy: 0.4237
# Epoch 8/10
# 11/11 [==============================] - 69s 6s/step - loss: 1.2864 - accuracy: 0.4156 - val_loss: 1.2588 - val_accuracy: 0.4504
# Epoch 9/10
# 11/11 [==============================] - 65s 5s/step - loss: 1.2767 - accuracy: 0.4252 - val_loss: 1.2474 - val_accuracy: 0.4771
# Epoch 10/10
# 11/11 [==============================] - 71s 6s/step - loss: 1.2659 - accuracy: 0.4433 - val_loss: 1.2390 - val_accuracy: 0.4847

# %%
melanoma_FPq.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 224, 224, 32)      1568
#
#  max_pooling2d_4 (MaxPoolin  (None, 56, 56, 32)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 53, 53, 64)        32832
#
#  max_pooling2d_5 (MaxPoolin  (None, 13, 13, 64)        0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 10816)             0
#
#  dense_4 (Dense)             (None, 64)                692288
#
#  dense_5 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 726948 (2.77 MB)
# Trainable params: 726948 (2.77 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# RMSprop is the best optimizer.
