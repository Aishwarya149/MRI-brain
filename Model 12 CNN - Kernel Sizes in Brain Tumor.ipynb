# %% [markdown]
# **Taking the best layers of 3 and find the best kernel sizes**

# %%
import imageio as Brain_tumorIGo
from matplotlib import pyplot as Brain_tumorOTp
import numpy as Brain_tumorPyn
import warnings as Brain_tumorWrn
Brain_tumorWrn.filterwarnings("ignore")

# %%
Route_of_Image='/MRI DATA/'

# %%
Brain_Tumor_Fi_1='training'
Brain_Tumor_Fi_2='validation'
Brain_Tumor_Fi_se=2
Brain_Tumor_Fi_size=(244,244)
Brain_Tumor_Fi_div=0.2

from tensorflow.keras.utils import image_dataset_from_directory as Brain_tumorASD

# Define the image size to match the model's input shape
Brain_Tumor_Fi_size = (224, 224)

Brain_tumor_TT = Brain_tumorASD(
    Route_of_Image,
    validation_split=Brain_Tumor_Fi_div,
    subset=Brain_Tumor_Fi_1,
    seed=Brain_Tumor_Fi_se,
    image_size=Brain_Tumor_Fi_size,
    batch_size=100
)
Brain_tumor_VV = Brain_tumorASD(
    Route_of_Image,
    validation_split=Brain_Tumor_Fi_div,
    subset=Brain_Tumor_Fi_2,
    seed=Brain_Tumor_Fi_se,
    image_size=Brain_Tumor_Fi_size,
    batch_size=100
)
# Out:
# Found 1311 files belonging to 4 classes.
# Using 1049 files for training.
# Found 1311 files belonging to 4 classes.
# Using 262 files for validation.

# %%
Brain_tumor_AA = 'tanh'
Brain_tumor_SS = (224, 224, 3)
Brain_tumor_S = 'softmax'
Brain_tumor_LL = 'SparseCategoricalCrossentropy'
#Brain_tumor_KR = (4, 4)

from keras.optimizers import Adam as Brain_tumor_OO
Brain_tumor_OOV = Brain_tumor_OO(learning_rate=0.0001)
from tensorflow.keras.models import Sequential as Brain_tumorASD1
from tensorflow.keras.layers import Conv2D as Brain_tumorASD2
from tensorflow.keras.layers import MaxPooling2D as Brain_tumorASD3
from tensorflow.keras.layers import Dense as Brain_tumorASD4
from tensorflow.keras.layers import Flatten as Brain_tumorASD5
from tensorflow.keras.layers import BatchNormalization as Brain_tumorASD6

# %% [markdown]
# ## **Model 2 - Kernel Sizes**

# %% [markdown]
# ### Building Kernel Size 2

# %%
Brain_tumor_KR = (2, 2)
Brain_tumor_OOV = Brain_tumor_OO(learning_rate=0.0001)
melanoma_FPq = Brain_tumorASD1([
    Brain_tumorASD2(32, kernel_size=Brain_tumor_KR, activation=Brain_tumor_AA, padding='same', input_shape=Brain_tumor_SS),
    Brain_tumorASD3(pool_size=(4,4)),

    Brain_tumorASD2(64, kernel_size=Brain_tumor_KR, activation=Brain_tumor_AA),
    Brain_tumorASD3(pool_size=(4,4)),
    Brain_tumorASD5(),

    Brain_tumorASD4(64, activation=Brain_tumor_AA),

    Brain_tumorASD4(4, activation='softmax')
    ])
melanoma_FPq.compile(optimizer= Brain_tumor_OOV, loss= Brain_tumor_LL, metrics=['accuracy'])
Brain_tumor_Hs =melanoma_FPq.fit(Brain_tumor_TT, validation_data= Brain_tumor_VV, epochs=10, batch_size=1000)
# Out:
# Epoch 1/10
# 11/11 [==============================] - 179s 7s/step - loss: 1.3244 - accuracy: 0.4004 - val_loss: 0.9738 - val_accuracy: 0.5916
# Epoch 2/10
# 11/11 [==============================] - 47s 4s/step - loss: 0.9210 - accuracy: 0.6549 - val_loss: 0.7214 - val_accuracy: 0.7863
# Epoch 3/10
# 11/11 [==============================] - 47s 4s/step - loss: 0.6994 - accuracy: 0.7626 - val_loss: 0.5810 - val_accuracy: 0.8092
# Epoch 4/10
# 11/11 [==============================] - 50s 4s/step - loss: 0.5914 - accuracy: 0.7903 - val_loss: 0.5438 - val_accuracy: 0.7863
# Epoch 5/10
# 11/11 [==============================] - 48s 4s/step - loss: 0.5569 - accuracy: 0.7903 - val_loss: 0.5097 - val_accuracy: 0.8244
# Epoch 6/10
# 11/11 [==============================] - 48s 4s/step - loss: 0.4981 - accuracy: 0.8189 - val_loss: 0.4633 - val_accuracy: 0.8473
# Epoch 7/10
# 11/11 [==============================] - 50s 4s/step - loss: 0.4391 - accuracy: 0.8303 - val_loss: 0.4433 - val_accuracy: 0.8473
# Epoch 8/10
# 11/11 [==============================] - 47s 4s/step - loss: 0.4249 - accuracy: 0.8332 - val_loss: 0.4232 - val_accuracy: 0.8550
# Epoch 9/10
# 11/11 [==============================] - 48s 4s/step - loss: 0.3852 - accuracy: 0.8541 - val_loss: 0.4273 - val_accuracy: 0.8359
# Epoch 10/10
# 11/11 [==============================] - 48s 4s/step - loss: 0.3612 - accuracy: 0.8618 - val_loss: 0.4049 - val_accuracy: 0.8435

# %%
melanoma_FPq.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      416
#
#  max_pooling2d (MaxPooling2  (None, 56, 56, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 55, 55, 64)        8256
#
#  max_pooling2d_1 (MaxPoolin  (None, 13, 13, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 10816)             0
#
#  dense (Dense)               (None, 64)                692288
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 701220 (2.67 MB)
# Trainable params: 701220 (2.67 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Building Kernel Size 3

# %%
Brain_tumor_KR = (3, 3)
Brain_tumor_OOV = Brain_tumor_OO(learning_rate=0.0001)
melanoma_FPq = Brain_tumorASD1([
    Brain_tumorASD2(32, kernel_size=Brain_tumor_KR, activation=Brain_tumor_AA, padding='same', input_shape=Brain_tumor_SS),
    Brain_tumorASD3(pool_size=(4,4)),

    Brain_tumorASD2(64, kernel_size=Brain_tumor_KR, activation=Brain_tumor_AA),
    Brain_tumorASD3(pool_size=(4,4)),
    Brain_tumorASD5(),

    Brain_tumorASD4(64, activation=Brain_tumor_AA),

    Brain_tumorASD4(4, activation='softmax')
    ])
melanoma_FPq.compile(optimizer= Brain_tumor_OOV, loss= Brain_tumor_LL, metrics=['accuracy'])
Brain_tumor_Hs =melanoma_FPq.fit(Brain_tumor_TT, validation_data= Brain_tumor_VV, epochs=10, batch_size=1000)
# Out:
# Epoch 1/10
# 11/11 [==============================] - 73s 6s/step - loss: 1.3652 - accuracy: 0.3785 - val_loss: 0.9990 - val_accuracy: 0.6069
# Epoch 2/10
# 11/11 [==============================] - 60s 5s/step - loss: 0.9185 - accuracy: 0.6473 - val_loss: 0.7635 - val_accuracy: 0.7519
# Epoch 3/10
# 11/11 [==============================] - 61s 5s/step - loss: 0.7145 - accuracy: 0.7464 - val_loss: 0.6335 - val_accuracy: 0.7863
# Epoch 4/10
# 11/11 [==============================] - 61s 5s/step - loss: 0.5864 - accuracy: 0.7893 - val_loss: 0.6001 - val_accuracy: 0.7863
# Epoch 5/10
# 11/11 [==============================] - 60s 5s/step - loss: 0.5353 - accuracy: 0.8170 - val_loss: 0.5476 - val_accuracy: 0.8092
# Epoch 6/10
# 11/11 [==============================] - 61s 5s/step - loss: 0.4573 - accuracy: 0.8303 - val_loss: 0.4914 - val_accuracy: 0.8511
# Epoch 7/10
# 11/11 [==============================] - 59s 5s/step - loss: 0.4043 - accuracy: 0.8561 - val_loss: 0.5005 - val_accuracy: 0.8359
# Epoch 8/10
# 11/11 [==============================] - 77s 7s/step - loss: 0.3791 - accuracy: 0.8675 - val_loss: 0.4606 - val_accuracy: 0.8359
# Epoch 9/10
# 11/11 [==============================] - 65s 5s/step - loss: 0.3477 - accuracy: 0.8932 - val_loss: 0.4290 - val_accuracy: 0.8473
# Epoch 10/10
# 11/11 [==============================] - 60s 5s/step - loss: 0.3112 - accuracy: 0.8990 - val_loss: 0.4202 - val_accuracy: 0.8359

# %%
melanoma_FPq.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 224, 224, 32)      896
#
#  max_pooling2d_2 (MaxPoolin  (None, 56, 56, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 54, 54, 64)        18496
#
#  max_pooling2d_3 (MaxPoolin  (None, 13, 13, 64)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 10816)             0
#
#  dense_2 (Dense)             (None, 64)                692288
#
#  dense_3 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 711940 (2.72 MB)
# Trainable params: 711940 (2.72 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Building Kernel Size 4

# %%
Brain_tumor_KR = (4, 4)
Brain_tumor_OOV = Brain_tumor_OO(learning_rate=0.0001)
melanoma_FPq = Brain_tumorASD1([
    Brain_tumorASD2(32, kernel_size=Brain_tumor_KR, activation=Brain_tumor_AA, padding='same', input_shape=Brain_tumor_SS),
    Brain_tumorASD3(pool_size=(4,4)),

    Brain_tumorASD2(64, kernel_size=Brain_tumor_KR, activation=Brain_tumor_AA),
    Brain_tumorASD3(pool_size=(4,4)),
    Brain_tumorASD5(),

    Brain_tumorASD4(64, activation=Brain_tumor_AA),

    Brain_tumorASD4(4, activation='softmax')
    ])
melanoma_FPq.compile(optimizer= Brain_tumor_OOV, loss= Brain_tumor_LL, metrics=['accuracy'])
Brain_tumor_Hs =melanoma_FPq.fit(Brain_tumor_TT, validation_data= Brain_tumor_VV, epochs=10, batch_size=1000)
# Out:
# Epoch 1/10
# 11/11 [==============================] - 80s 7s/step - loss: 1.2660 - accuracy: 0.4490 - val_loss: 0.9736 - val_accuracy: 0.6107
# Epoch 2/10
# 11/11 [==============================] - 81s 7s/step - loss: 0.8703 - accuracy: 0.6826 - val_loss: 0.7647 - val_accuracy: 0.6908
# Epoch 3/10
# 11/11 [==============================] - 79s 7s/step - loss: 0.6596 - accuracy: 0.7560 - val_loss: 0.5893 - val_accuracy: 0.7977
# Epoch 4/10
# 11/11 [==============================] - 77s 6s/step - loss: 0.5417 - accuracy: 0.8112 - val_loss: 0.5509 - val_accuracy: 0.8015
# Epoch 5/10
# 11/11 [==============================] - 76s 6s/step - loss: 0.4717 - accuracy: 0.8275 - val_loss: 0.4748 - val_accuracy: 0.8092
# Epoch 6/10
# 11/11 [==============================] - 75s 6s/step - loss: 0.4030 - accuracy: 0.8570 - val_loss: 0.4719 - val_accuracy: 0.7977
# Epoch 7/10
# 11/11 [==============================] - 79s 7s/step - loss: 0.3697 - accuracy: 0.8837 - val_loss: 0.4199 - val_accuracy: 0.8206
# Epoch 8/10
# 11/11 [==============================] - 77s 6s/step - loss: 0.3220 - accuracy: 0.9037 - val_loss: 0.4021 - val_accuracy: 0.8550
# Epoch 9/10
# 11/11 [==============================] - 81s 7s/step - loss: 0.3022 - accuracy: 0.9037 - val_loss: 0.4106 - val_accuracy: 0.8435
# Epoch 10/10
# 11/11 [==============================] - 78s 7s/step - loss: 0.2794 - accuracy: 0.9133 - val_loss: 0.3687 - val_accuracy: 0.8626

# %%
melanoma_FPq.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 224, 224, 32)      1568
#
#  max_pooling2d_4 (MaxPoolin  (None, 56, 56, 32)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 53, 53, 64)        32832
#
#  max_pooling2d_5 (MaxPoolin  (None, 13, 13, 64)        0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 10816)             0
#
#  dense_4 (Dense)             (None, 64)                692288
#
#  dense_5 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 726948 (2.77 MB)
# Trainable params: 726948 (2.77 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Kernel Size 4 is best.
